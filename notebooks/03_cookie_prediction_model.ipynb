# %%
import pandas as pd
import numpy as np

# %%
import os

os.getcwd()
# Out:
# '/Users/abbygoblick/cookie-lab/notebooks'

# %%
cookie_model = pd.read_pickle(
    "cookie_model.pkl"
)

# %%
cookie_model.shape
# Out:
# (475, 63)
